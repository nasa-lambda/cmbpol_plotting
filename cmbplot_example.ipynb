# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
pylab.rcParams['figure.figsize'] = (10, 6)
import matplotlib.pyplot as plt
import numpy as np
import plotting
plt.rcParams.update({'font.size':18})
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cmbplot = plotting.Plotting()
cmbplot.default_TT_plot()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
cmbplot = plotting.Plotting(degreescale=True)
cmbplot.default_EE_plot()

# %%
cmbplot = plotting.Plotting('TE', degreescale=True)
cmbplot.default_TE_plot()

# %%
cmbplot = plotting.Plotting()
cmbplot.default_BB_plot()

# %%
cmbplot = plotting.Plotting()
cmbplot.default_lensing_plot()

# %%
cmbplot.list_experiments('TT')
cmbplot.list_experiments('TE')
cmbplot.list_experiments('EE')
cmbplot.list_experiments('BB')
cmbplot.list_experiments('lensing')
# Out:
# ['Planck_COM_PowerSp', 'Planck_Plik_lite', 'ACTPol', 'SPT']
# ['SPTpol_2015', 'BICEP2/Keck_2015', 'ACTPol_2016', 'Planck_2015', 'WMAP_2013']
# ['SPTpol_2015', 'BICEP2/Keck_2015', 'ACTPol_2016', 'Planck_2015', 'WMAP_2013']
# ['BICEP1', 'SPTpol', 'BICEP2', 'QUIET-Q', 'CAPMAP', 'ACTPol', 'BICEP2+Keck/Planck', 'WMAP', 'QUIET-W', 'DASI', 'CBI', 'QUaD', 'BOOMERanG', 'BICEP2+Keck', 'MAXIPOL', 'POLARBEAR']
# ['ACT_2013', 'BICEP2/Keck_2016', 'Planck_2015', 'SPTpol_2015', 'ACTPol_2016', 'POLARBEAR_2014', 'SPT_2012']
